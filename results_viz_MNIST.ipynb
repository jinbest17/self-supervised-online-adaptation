# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

from 

saved = pickle.load(open("mnist_results.p","rb"))

saved2 = pickle.load(open("mnist_resultsnoise.p","rb"))

# %%
print(saved
     )
# Out:
# {'results_noise': [7, 2, 2, 0, 4, 4, 4, 9, 5, 9, 0, 6, 9, 0, 1, 5, 9, 7, 8, 4, 9, 6, 6, 5, 4, 0, 7, 4, 0, 8, 3, 1, 3, 4, 7, 2, 7, 1, 2, 4, 4, 7, 4, 2, 3, 5, 1, 2, 4, 4, 6, 3, 5, 5, 6, 0, 4, 4, 9, 9, 7, 8, 9, 2, 7, 4, 6, 4, 3, 0, 7, 0, 2, 8, 1, 7, 3, 2, 4, 7, 7, 6, 2, 7, 8, 4, 7, 3, 6, 1, 3, 6, 4, 3, 1, 4, 1, 7, 6, 9, 6, 0, 5, 4, 9, 9, 2, 8, 4, 4, 8, 7, 3, 9, 7, 4, 4, 4, 9, 2, 5, 4, 7, 6, 7, 4, 0, 5, 8, 5, 6, 6, 5, 7, 8, 1, 0, 1, 6, 4, 6, 7, 3, 1, 7, 1, 8, 2, 0, 2, 9, 8, 5, 5, 4, 5, 6, 0, 5, 4, 4, 6, 5, 4, 6, 5, 4, 5, 1, 4, 4, 7, 2, 3, 2, 7, 1, 8, 1, 8, 1, 8, 5, 0, 8, 9, 2, 5, 0, 8, 8, 4, 0, 9, 0, 3, 1, 6, 4, 2, 8, 6, 1, 1, 8, 3, 9, 5, 2, 4, 4, 5, 9, 3, 9, 0, 3, 4, 5, 5, 9, 2, 2, 7, 4, 2, 8, 4, 4, 7, 3, 3, 8, 8, 7, 9, 2, 2, 4, 1, 5, 9, 8, 7, 2, 3, 0, 2, 4, 2, 4, 4, 9, 5, 7, 7, 2, 8, 2, 0, 8, 5, 7, 7, 8, 1, 8, 1, 8, 0, 3, 0, 1, 9, 9, 4, 1, 8, 2, 1, 2, 9, 7, 5, 9, 2, 6, 4, 4, 5, 8, 2, 4, 2, 0, 4, 0, 0, 2, 8, 4, 7, 8, 8, 4, 0, 2, 7, 4, 3, 3, 0, 0, 3, 1, 9, 6, 5, 2, 5, 8, 2, 9, 3, 7, 4, 2
# ...

# %%
count = 0
for i in range(len(saved['results_rotate'])):
    if saved['results_rotate'][i] == saved['true_label'][i]:
        count+=1
print(count /len(saved['results_rotate']) )
# Out:
# 0.111875

# %%
count = 0
for i in range(len(saved['results_perm'])):
    if saved['results_perm'][i] == saved['true_label'][i]:
        count+=1
print(count /len(saved['results_rotate']) )
# Out:
# 0.123125

# %%
count = 0
for i in range(len(saved['results_noise'])):
    if saved['results_noise'][i] == saved['true_label'][i]:
        count+=1
print(count /len(saved['results_noise']) )
# Out:
# 0.9559375

# %%
results= saved['results_noise']
countnum = 0
results_100 = []
stepSize = 100
print(len(results))


for step in range(0,32):
  countnum = 0
  
  for i in range(stepSize):
      if results[i +step*stepSize] != saved['true_label'][i+step*stepSize]:
          countnum+=1
  print(1-countnum/stepSize)
  results_100.append(1-countnum/stepSize)
indices = np.arange(32)
indices = indices * 100
print(indices)
plt.plot( indices,results_100)
plt.ylim([0, 1])
plt.show()
# Out:
# 3200
# 0.88
# 0.91
# 0.87
# 0.95
# 0.97
# 0.95
# 0.97
# 0.97
# 0.99
# 0.95
# 0.95
# 0.99
# 0.94
# 0.94
# 0.96
# 0.94
# 0.96
# 0.97
# 0.96
# 0.97
# 0.95
# 0.9299999999999999
# 0.99
# 0.97
# 0.96
# 0.98
# 0.97
# 0.96
# 0.99
# 0.96
# 0.96
# 0.98
# [   0  100  200  300  400  500  600  700  800  900 1000 1100 1200 1300
#  1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700
#  2800 2900 3000 3100]

# %%
results= saved['results_noise']
countnum = 0
results_100 = []
stepSize = 100
print(len(results))


for step in range(0,32):
  countnum = 0
  
  for i in range(stepSize):
      if results[i +step*stepSize] != saved['true_label'][i+step*stepSize]:
          countnum+=1
  print(1-countnum/stepSize)
  results_100.append(1-countnum/stepSize)
indices = np.arange(32)
indices = indices * 100
print(indices)
plt.plot( indices,results_100)
plt.ylim([0, 1])
plt.show()
# Out:
# 3200
# 0.9
# 0.9299999999999999
# 0.92
# 0.95
# 0.86
# 0.89
# 0.89
# 0.91
# 0.97
# 0.95
# 0.96
# 0.94
# 0.87
# 0.87
# 0.88
# 0.86
# 0.92
# 0.9
# 0.9
# 0.91
# 0.9
# 0.86
# 0.91
# 0.91
# 0.87
# 0.89
# 0.83
# 0.88
# 0.89
# 0.8200000000000001
# 0.9
# 0.88
# [   0  100  200  300  400  500  600  700  800  900 1000 1100 1200 1300
#  1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700
#  2800 2900 3000 3100]

# %%
results= saved['results_rotate']
countnum = 0
results_100 = []
stepSize = 100
print(len(results))


for step in range(0,32):
  countnum = 0
  
  for i in range(stepSize):
      if results[i +step*stepSize] != saved['true_label'][i+step*stepSize]:
          countnum+=1
  print(1-countnum/stepSize)
  results_100.append(1-countnum/stepSize)
indices = np.arange(32)
indices = indices * 100
print(indices)
plt.plot( indices,results_100)
plt.ylim([0, 1])
plt.show()
# Out:
# 3200
# 0.14
# 0.09999999999999998
# 0.16000000000000003
# 0.10999999999999999
# 0.15000000000000002
# 0.13
# 0.13
# 0.10999999999999999
# 0.09999999999999998
# 0.10999999999999999
# 0.07999999999999996
# 0.09999999999999998
# 0.16000000000000003
# 0.06999999999999995
# 0.08999999999999997
# 0.14
# 0.06999999999999995
# 0.18999999999999995
# 0.09999999999999998
# 0.08999999999999997
# 0.08999999999999997
# 0.09999999999999998
# 0.09999999999999998
# 0.13
# 0.07999999999999996
# 0.09999999999999998
# 0.10999999999999999
# 0.14
# 0.07999999999999996
# 0.06999999999999995
# 0.15000000000000002
# 0.09999999999999998
# [   0  100  200  300  400  500  600  700  800  900 1000 1100 1200 1300
#  1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700
#  2800 2900 3000 3100]
